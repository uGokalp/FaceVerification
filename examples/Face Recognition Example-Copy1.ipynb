# %%
from faceverification import recognition

# %%
dir(recognition)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'display_image',
#  'extract_face',
#  'get_embedding',
#  'get_model',
#  'load_image',
#  'recognition',
#  'utils',
#  'verify',
#  'vgg']

# %%
recognition
# Out:
# <module 'faceverification.recognition' from '/Users/mac/Projects/faceverification/faceverification/recognition/__init__.py'>

# %%
img = recognition.load_image("../images/1.PNG")

# %%
model = recognition.get_model()

# %%
recognition.verify(img, img, model)
# Out:
# (True, 0.0)
